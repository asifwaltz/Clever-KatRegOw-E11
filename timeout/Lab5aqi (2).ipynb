# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("pleaseWork.csv")

tempData = data.loc[145 : 441, "time" : "temp"]
gasData = data.loc[145 : 441, "time" : "gas" : 2]
humData = data.loc[145 : 441, "time" : "humidity" : 3]
presData = data.loc[145 : 441, "time" : "pressure" : 4]
altData = data.loc[145 : 441, "time" : "alt" : 5]
std10Data = data.loc[145 : 441, "time" : "stndr10" : 6]
std25Data = data.loc[145 : 441, "time" : "stndr25" : 7]
std100Data = data.loc[145 : 441, "time" : "stndr100" : 8]
env10Data = data.loc[145 : 441, "time" : "enviro10" : 9]
env25Data = data.loc[145 : 441, "time" : "enviro25" : 10]
env100Data = data.loc[145 : 441, "time" : "enviro100" : 11]
p03Data = data.loc[145 : 441, "time" : "p03um" : 12]
p05Data = data.loc[145 : 441, "time" : "p05um" : 13]
p10Data = data.loc[145 : 441, "time" : "p10um" : 14]
p25Data = data.loc[145 : 441, "time" : "p25um" : 15]
p50Data = data.loc[145 : 441, "time" : "p50um" : 16]
p100Data = data.loc[145 : 441, "time" : "p100um" : 17]

plt.plot(tempData["time"], tempData["temp"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Temperature")
plt.title("Temperature vs Time")
plt.show()

plt.plot(gasData["time"], gasData["gas"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Gas")
plt.title("Gas vs Time")
plt.show()

plt.plot(humData["time"], humData["humidity"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Humidity")
plt.title("Humidity vs Time")
plt.show()

plt.plot(presData["time"], presData["pressure"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Pressure")
plt.title("Pressure vs Time")
plt.show()

plt.plot(altData["time"], altData["alt"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Altitude")
plt.title("Altitude vs Time")
plt.show()

plt.plot(std10Data["time"], std10Data["stndr10"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Standard 10")
plt.title("Standard 10 vs Time")
plt.show()

plt.plot(std25Data["time"], std25Data["stndr25"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Standard 25")
plt.title("Standard 25 vs Time")
plt.show()

plt.plot(std100Data["time"], std100Data["stndr100"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Standard 100")
plt.title("Standard 100 vs Time")
plt.show()

plt.plot(env10Data["time"], env10Data["enviro10"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Environment 10")
plt.title("Environment 10 vs Time")
plt.show()

plt.plot(env25Data["time"], env25Data["enviro25"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Environment 25")
plt.title("Environment 25 vs Time")
plt.show()

plt.plot(env100Data["time"], env100Data["enviro100"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Environment 100")
plt.title("Environment 100 vs Time")
plt.show()

plt.plot(p03Data["time"], p03Data["p03um"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Particles 0.3um")
plt.title("Particles 0.3um vs Time")
plt.show()

plt.plot(p05Data["time"], p05Data["p05um"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Particles 0.5um")
plt.title("Particles 0.5um vs Time")
plt.show()

plt.plot(p10Data["time"], p10Data["p10um"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Particles 1.0um")
plt.title("Particles 1.0um vs Time")
plt.show()

plt.plot(p25Data["time"], p25Data["p25um"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Particles 2.5um")
plt.title("Particles 2.5um vs Time")
plt.show()

plt.plot(p50Data["time"], p50Data["p50um"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Particles 5.0um")
plt.title("Particles 5.0um vs Time")
plt.show()

plt.plot(p100Data["time"], p100Data["p100um"])
plt.xlabel("Time")
plt.xticks([0, 295])
plt.ylabel("Particles 10.0um")
plt.title("Particles 10.0um vs Time")
plt.show()

nBinsTemp = int((np.max(tempData["temp"]) - np.min(tempData["temp"])) * 5)
nBinsGas = int((np.max(gasData["gas"]) - np.min(gasData["gas"])) * 5)
nBinsHum = int((np.max(humData["humidity"]) - np.min(humData["humidity"])) * 5)
nBinsPres = int((np.max(presData["pressure"]) - np.min(presData["pressure"])) * 5)
nBinsAlt = int((np.max(altData["alt"]) - np.min(altData["alt"])) * 5)
nBinsStd10 = int((np.max(std10Data["stndr10"]) - np.min(std10Data["stndr10"])) * 5)
nBinsStd25 = int((np.max(std25Data["stndr25"]) - np.min(std25Data["stndr25"])) * 5)
nBinsStd100 = int((np.max(std100Data["stndr100"]) - np.min(std100Data["stndr100"])) * 5)
nBinsEnv10 = int((np.max(env10Data["enviro10"]) - np.min(env10Data["enviro10"])) * 5)
nBinsEnv25 = int((np.max(env25Data["enviro25"]) - np.min(env25Data["enviro25"])) * 5)
nBinsEnv100 = int((np.max(env100Data["enviro100"]) - np.min(env100Data["enviro100"])) * 5)
nBinsP03 = int((np.max(p03Data["p03um"]) - np.min(p03Data["p03um"])) * 5)
nBinsP05 = int((np.max(p05Data["p05um"]) - np.min(p05Data["p05um"])) * 5)
nBinsP10 = int((np.max(p10Data["p10um"]) - np.min(p10Data["p10um"])) * 5)
nBinsP25 = int((np.max(p25Data["p25um"]) - np.min(p25Data["p25um"])) * 5)
nBinsP50 = int((np.max(p50Data["p50um"]) - np.min(p50Data["p50um"])) * 5)
nBinsP100 = int((np.max(p100Data["p100um"]) - np.min(p100Data["p100um"])) * 5)

# %%
plt.hist(tempData["temp"], bins = nBinsTemp)
plt.xlabel("Temperature")
plt.title("Temperature vs Time")

plt.hist(gasData["gas"], bins = nBinsGas)
plt.xlabel("Gas")
plt.title("Gas vs Time")
plt.show()

plt.hist(humData["humidity"], bins = nBinsHum)
plt.xlabel("Humidity")
plt.title("Humidity vs Time")
plt.show()

plt.hist(presData["pressure"], bins = nBinsPres)
plt.xlabel("Pressure")
plt.title("Pressure vs Time")
plt.show()

plt.hist(altData["alt"], bins = nBinsAlt)
plt.xlabel("Altitude")
plt.title("Altitude vs Time")
plt.show()

plt.hist(std10Data["stndr10"], bins = nBinsStd10)
plt.xlabel("Standard 10")
plt.title("Standard 10 vs Time")
plt.show()

plt.hist(std25Data["stndr25"], bins = nBinsStd25)
plt.xlabel("Standard 25")
plt.title("Standard 25 vs Time")
plt.show()

plt.hist(std100Data["stndr100"], bins = nBinsStd100)
plt.xlabel("Standard 100")
plt.title("Standard 100 vs Time")
plt.show()

plt.hist(env10Data["enviro10"], bins = nBinsEnv10)
plt.xlabel("Environmental 10")
plt.title("Environmental 10 vs Time")
plt.show()

plt.hist(env25Data["enviro25"], bins = nBinsEnv25)
plt.xlabel("Environmental 25")
plt.title("Environmental 25 vs Time")
plt.show()

plt.hist(env100Data["enviro100"], bins = nBinsEnv100)
plt.xlabel("Environmental 100")
plt.title("Environmental 100 vs Time")
plt.show()

plt.hist(p03Data["p03um"], bins = nBinsP03)
plt.xlabel("Particles 0.3um")
plt.title("Particles 0.3um vs Time")
plt.show()

plt.hist(p05Data["p05um"], bins = nBinsP05)
plt.xlabel("Particles 0.5um")
plt.title("Particles 0.5um vs Time")
plt.show()

plt.hist(p10Data["p10um"], bins = nBinsP10)
plt.xlabel("Particles 1.0um")
plt.title("Particles 1.0um vs Time")
plt.show()

plt.hist(p25Data["p25um"], bins = nBinsP25)
plt.xlabel("Particles 2.5um")
plt.title("Particles 2.5um vs Time")
plt.show()

plt.hist(p50Data["p50um"], bins = nBinsP50)
plt.xlabel("Particles 5.0um")
plt.title("Particles 5.0um vs Time")
plt.show()

plt.hist(p100Data["p100um"], bins = nBinsP100)
plt.xlabel("Particles 10.0um")
plt.title("Particles 10.0um vs Time")
plt.show()
