# %% [markdown]
# - 1.
#   - 5. No change.
#   - 6. Like maybe 3 volts?

# %% [markdown]
# ![bad](http://localhost:8888/files/python_scripts/E11/lab/Lab9/Q1.jpeg?_xsrf=2%7C2f936f55%7C6ed3c5feadfddfdf0a885a31f647e0a2%7C1775525892)
# 1M ohm resister

# %% [markdown]
# - 2.
#   - a.
#     - 7. smth
#     - 8. smth
#   - b.
#     - 3. smth
#     - 4. smth
#     - 6. smth
#     - 7. smth

# %% [markdown]
# - 4. 29.07 volts, 0.22F

# %% [markdown]
# ![meow](http://localhost:8888/files/python_scripts/E11/lab/Lab9/Q4%2C1.jpg?_xsrf=2%7C2f936f55%7C6ed3c5feadfddfdf0a885a31f647e0a2%7C1775525892)
# 68 ohm resistor

# %% [markdown]
# ![woof](http://localhost:8888/files/python_scripts/E11/lab/Lab9/Q4%2C2.jpeg?_xsrf=2%7C2f936f55%7C6ed3c5feadfddfdf0a885a31f647e0a2%7C1775525892)
# 1k ohm resistor

# %% [markdown]
# - 5.
#    - 1. We have more noise, shape less defined.
#    - 2. It's more sensitive, so it is picking up on more background activity.
#    - 4. Could increase the resistance or the capacitance. Increasing the resistance would decrease the voltage that enters the boost converter, making it less receptive to sense things. Increasing the capacitance would mean the capacitor would take longer to charge, thus take more time.
#    - 5. The higher resistor had a slower drop off than the lower.
#    - 6. They are looking like as expected - there is a higher peak when a source is near and that peak has a rapid up and then gradual drop off (decay).
#    - 7. No, they vary. To make it the most pretty, higher resolution (more bits) and higher frequency (sampling rate).
