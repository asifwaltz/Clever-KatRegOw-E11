# %% [markdown]
# - 1.
#   - b. The longer, bent end (anode) needs to be connected to the +5v and the shorter (cathode) connects to ground.
#   - c. 1.7, this is lower than expected, which means the LED has more resistance than the resistor.
#   - d. 3.4, which is expected.
#   - f. It should get brighter, since there's more voltage being allowed to flow through it.
#   - g. To restrict/allow voltage flow.
#   - h.
#     - 5.6k ohm: dimmer than 150 ohm
#     - 47k ohm: super dim, more so than 5.6k
#     - 330 ohm: much brighter than last two
#   - i.
#     - 5.6k ohm -  LED: 2.63 - 2.6 V drop
#     - 47k ohm - LED: 2.75 - 2.4 V drop
#     - 330 ohm - LED: 2.1 - 3.0 V drop
#   - j. The brightness should go down; there's less voltage input. It did in fact dim.
# - 2.
#   - m. 8.6 V drop accross boost converter
#   - o. Brightness increased
#   - p. 47K ohm - LED: 6.88 - 1.78 V drop
#   - q.
#     - Green brighter than red; 47k ohm - LED: 6.411 - 2.19 V drop
#     - Blue ; 47k ohm - LED: 6.1 - 2.49 V drop
#     - Yellow is dimmest; 47k ohm - LED: 6.8 - 1.79 V drop
# - 3.
#   - b. Very little, 0.01 V drop
#   - c. Covering the light reduces the V drop (cuz less voltage in system overall) and increasing to 10V input increases the V drop
#   - d. 0.021 V drop
#   - e. No
#   - f. 0.04 V drop
#   - g. 8.6 V
